# %%
import sys
sys.path.append('..')
from src.analyse_utils_pytorch import plot_history
from src.resnet_pytorch import ResNet
from src.model_utils_pytorch import train_model, save_model
from torch.optim import Adam

# %%
model = ResNet()
model, history = train_model(model=model, optimizer=Adam(model.parameters(), lr=1e-4), epochs=1000)
# Out:
# Epoch 0/999:	train Loss: 2.3019 Acc: 0.1229	val Loss: 2.3026 Acc: 0.1000
# Epoch 1/999:	train Loss: 2.2835 Acc: 0.1864	val Loss: 2.3024 Acc: 0.2333
# Epoch 2/999:	train Loss: 2.2797 Acc: 0.1695	val Loss: 2.3018 Acc: 0.2667
# Epoch 3/999:	train Loss: 2.2715 Acc: 0.1949	val Loss: 2.3015 Acc: 0.2000
# Epoch 4/999:	train Loss: 2.2646 Acc: 0.2119	val Loss: 2.3014 Acc: 0.1667
# Epoch 5/999:	train Loss: 2.2361 Acc: 0.2288	val Loss: 2.3008 Acc: 0.1333
# Epoch 6/999:	train Loss: 2.2352 Acc: 0.2119	val Loss: 2.2995 Acc: 0.2333
# Epoch 7/999:	train Loss: 2.2604 Acc: 0.1568	val Loss: 2.2986 Acc: 0.2333
# Epoch 8/999:	train Loss: 2.2692 Acc: 0.1695	val Loss: 2.2987 Acc: 0.2667
# Epoch 9/999:	train Loss: 2.2424 Acc: 0.1949	val Loss: 2.2986 Acc: 0.3000
# Epoch 10/999:	train Loss: 2.2406 Acc: 0.2076	val Loss: 2.2974 Acc: 0.3667
# Epoch 11/999:	train Loss: 2.2374 Acc: 0.2331	val Loss: 2.2991 Acc: 0.3333
# Epoch 12/999:	train Loss: 2.2181 Acc: 0.2669	val Loss: 2.2984 Acc: 0.3333
# ...

# %%
plot_history(history)

# %%
save_model(model, history, 'resnet_pytorch')

# %%
model = ResNet()
model, history = train_model(model=model, optimizer=Adam(model.parameters(), lr=1e-4), epochs=1000)
# Out:
# Epoch 0/999:	train Loss: 2.2986 Acc: 0.1186	val Loss: 2.3025 Acc: 0.2667
# Epoch 1/999:	train Loss: 2.3024 Acc: 0.0975	val Loss: 2.3024 Acc: 0.2000
# Epoch 2/999:	train Loss: 2.2931 Acc: 0.1483	val Loss: 2.3020 Acc: 0.2667
# Epoch 3/999:	train Loss: 2.2986 Acc: 0.1441	val Loss: 2.3014 Acc: 0.3000
# Epoch 4/999:	train Loss: 2.2964 Acc: 0.1483	val Loss: 2.3009 Acc: 0.3333
# Epoch 5/999:	train Loss: 2.2844 Acc: 0.1610	val Loss: 2.3001 Acc: 0.3000
# Epoch 6/999:	train Loss: 2.2737 Acc: 0.2119	val Loss: 2.2996 Acc: 0.4667
# Epoch 7/999:	train Loss: 2.2620 Acc: 0.1864	val Loss: 2.2971 Acc: 0.4333
# Epoch 8/999:	train Loss: 2.2528 Acc: 0.2034	val Loss: 2.2949 Acc: 0.4000
# Epoch 9/999:	train Loss: 2.2689 Acc: 0.2288	val Loss: 2.2932 Acc: 0.3667
# Epoch 10/999:	train Loss: 2.2515 Acc: 0.2161	val Loss: 2.2880 Acc: 0.4333
# Epoch 11/999:	train Loss: 2.1832 Acc: 0.3602	val Loss: 2.2562 Acc: 0.3667
# Epoch 35/999:	train Loss: 2.1926 Acc: 0.3390	val Loss: 2.2678 Acc: 0.4667
# ...

# %%
plot_history(history)

# %%
print(model)
# Out:
# ResNet(
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (dropout): Dropout(p=0.5)
#   (id): IdentityBLock(
#     (conv): Conv2d (32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#   )
#   (conv1): Conv2d (3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): ConvBlock(
#     (conv1): Conv2d (32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True)
#     (conv2): Conv2d (32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (relu): ReLU(inplace)
#   )
#   (conv3): ConvBlock(
#     (conv1): Conv2d (64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     (conv2): Conv2d (64, 128, kernel_size=(3, 3), stride=(1, 1))
# ...

# %%
save_model(model, history, 'resnet_pytorch2')
